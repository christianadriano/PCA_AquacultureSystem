# %% [markdown]
# <a href="https://colab.research.google.com/github/christianadriano/PCA_AquacultureSystem/blob/master/PCA_Kmeans_Environment_Piscicultura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tables for data wrangling
import numpy as np #basic statistical methods 
import io #for uploading data

#Manual option
from google.colab import files
uploaded = files.upload() #choose file dados_relativizados_carcinicultura.csv
# Out:
#      <input type="file" id="files-664d0e3d-f196-40c9-89a2-18393dcae32a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-664d0e3d-f196-40c9-89a2-18393dcae32a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_carcinicultura.csv to dados_relativizados_centralizados_carcinicultura.csv

# %%
#Upload data from cvs file
df = pd.read_csv(io.StringIO(uploaded['dados_relativizados_centralizados_carcinicultura.csv'].decode('utf-8'))) 
print(df)

# %%
column_names = df.columns
#Select fatores Ambientais 
feature_names = [name for name in column_names if name.startswith("A")] 

#feature_names = list(df.columns["A2_DA":"A4_EUC"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo = df[list_names]
df_cultivo.head()

# %%
#Look at correlations 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

corr = df_cultivo.corr()

# using a styled panda's dataframe from https://stackoverflow.com/a/42323184/1215012
cmap = 'coolwarm'

def magnify():
    return [dict(selector="th", props=[("font-size", "7pt")]),
            dict(selector="td", props=[('padding', "0em 0em")]),
            dict(selector="th:hover", props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover", 
                 props=[('max-width', '200px'), ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %%
#smaller chart
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='coolwarm')

# %%
#check which ones are statiscally significant
from scipy.stats import pearsonr
import pandas as pd

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

p_values = calculate_pvalues(df_cultivo)

cmap = 'coolwarm'

def magnify():
    return [dict(selector="th", props=[("font-size", "7pt")]),
            dict(selector="td", props=[('padding', "0em 0em")]),
            dict(selector="th:hover", props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover", 
                 props=[('max-width', '200px'), ('font-size', '12pt')])
]

p_values.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002 th {
#           font-size: 7pt;
#     }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002 td {
#           padding: 0em 0em;
#     }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002 th:hover {
#           font-size: 12pt;
#     }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col0 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col1 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col2 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col3 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col4 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col5 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col6 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col7 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col8 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col9 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col10 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col11 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col12 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col13 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col14 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row0_col15 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col0 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col1 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col2 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col3 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col4 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col5 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col6 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col7 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col8 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col9 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col10 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col11 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col12 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col13 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col14 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row1_col15 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col0 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col1 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col2 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col3 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col4 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col5 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col6 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col7 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col8 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col9 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col10 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col11 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col12 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col13 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col14 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row2_col15 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col0 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col1 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col2 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col3 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col4 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col5 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col6 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col7 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col8 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col9 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col10 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col11 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_d8aa_11ea_bf4e_0242ac1c0002row3_col12 {
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_986f0ea2_

# %%
#p_values.isnull(p_values.array([np.nan, 0], dtype=float))
p_values =p_values.fillna(0)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

np.random.seed(101)
zvals = np.random.rand(100, 100) * 10

# make a color map of fixed colors
cmap_discrete = colors.ListedColormap(['green', 'lightgrey'])
bounds=[0,0.05,1]
norm = colors.BoundaryNorm(bounds, cmap_discrete.N)

# tell imshow about color map so that only set colors are used
img = plt.imshow(zvals, interpolation='nearest', origin='lower',
                    cmap=cmap_discrete, norm=norm)

sns.heatmap(p_values, xticklabels=p_values.columns, yticklabels=p_values.columns, cmap=cmap_discrete, norm=norm)

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, df_cultivo[['cultivo']]], axis = 1)

# %%
#Visualize results of PCA
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()
print(targets)
for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , s = 100)
   
#for names in feature_names:  
#    ax.annotate(txt, (z[i], y[i]))

ax.legend(targets)
ax.grid()
# Out:
# ['M. rosenbergii - Espirito Santo-'
#  'P. vannamei - Sergipe - Semi intensivo' 'L. vannamei - Aquafort'
#  'L. vannamei - Northern' 'L. vannamei - Aquacrusta' 'L. vannamei - HM'
#  'L. vannamei - Ilha' 'L. vannamei - Carpixe' 'L. vannamei - Marinus'
#  'L. vannamei - Aquabrasilis' 'L. vannamei - Aquarium - baixa densid.'
#  'L. vannamei - Aquarium - alta densis'
#  'L. vannamei - Aquarium-  bifasico']

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.34023213 0.20209521]
# total variance explained: 0.5423273442182176

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1])}, columns=['cultivo', 'pc1','pc2'])
#df_clustering

# %%
df_clustering.iloc[:,2]
#df_clustering.iloc[:,1]
# Out:
# 0    -0.073283
# 1     5.490187
# 2    -0.658878
# 3    -1.941160
# 4    -0.526917
# 5    -0.062581
# 6     0.586027
# 7     0.638037
# 8     0.703847
# 9     3.736575
# 10   -2.919138
# 11   -2.634247
# 12   -2.338471
# Name: pc1, dtype: float64

# %%
#Find clusters 
from sklearn.cluster import KMeans
#4 clusters
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the

# %%
#5 clusters
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the

# %% [markdown]
# In my view, we have two large clusters and three outliers, as the graph above shows.

# %%
#6 clusters
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

#7 clusters

# %%
#Find distances among clusters
