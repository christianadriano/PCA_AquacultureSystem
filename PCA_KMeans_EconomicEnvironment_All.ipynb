# %% [markdown]
# <a href="https://colab.research.google.com/github/christianadriano/PCA_AquacultureSystem/blob/master/PCA_KMeans_EconomicEnvironment_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tables for data wrangling
import numpy as np #basic statistical methods 
import io #for uploading data

#Manual option
from google.colab import files
uploaded1 = files.upload() #choose file dados_relativizados_carcinicultura.csv
# Out:
#      <input type="file" id="files-685d4c46-c55a-4ef3-b6d9-1cdc2d319ccc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-685d4c46-c55a-4ef3-b6d9-1cdc2d319ccc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_carcinicultura.csv to dados_relativizados_centralizados_carcinicultura.csv

# %%
#Upload data from cvs file
df1 = pd.read_csv(io.StringIO(uploaded1['dados_relativizados_centralizados_carcinicultura.csv'].decode('utf-8'))) 
print(df1)
# Out:
#     Unnamed: 0         cultura  ...    S19_IR    S20_IE
# 0            0  Carcinicultura  ... -0.015126 -0.181345
# 1            1  Carcinicultura  ... -3.007332  1.033912
# 2            2  Carcinicultura  ...  0.028468 -1.738392
# 3            3  Carcinicultura  ...  0.168525 -0.540663
# 4            4  Carcinicultura  ...  0.038207 -0.549427
# 5            5  Carcinicultura  ...  0.245973 -0.540663
# 6            6  Carcinicultura  ...  0.068815  1.393230
# 7            7  Carcinicultura  ... -0.217791 -0.937959
# 8            8  Carcinicultura  ... -0.385673 -1.043125
# 9            9  Carcinicultura  ... -0.217791  1.895692
# 10          10  Carcinicultura  ...  1.097908  0.402913
# 11          11  Carcinicultura  ...  1.097908  0.402913
# 12          12  Carcinicultura  ...  1.097908  0.402913
#
# [13 rows x 50 columns]

# %%
column_names = df1.columns
#Select fatores Economicos e Ambientais 
feature_names = [name for name in column_names if( name.startswith("E") | name.startswith("A")) ] 

#feature_names = list(df.columns["E1_RRLII":"E13_DM"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo_1 = df1[list_names]
df_cultivo_1.head()
# Out:
#                                   cultivo  E1_RRLII  ...        A3_PRF    A4_EUC
# 0        M. rosenbergii - Espirito Santo- -0.942112  ...  1.450000e-10 -3.354904
# 1  P. vannamei - Sergipe - Semi intensivo  2.444167  ... -1.695427e+00  0.990997
# 2                  L. vannamei - Aquafort -0.777345  ...  6.545044e-01  0.322879
# 3                  L. vannamei - Northern -0.738076  ...  1.825333e+00  0.071943
# 4                L. vannamei - Aquacrusta -0.213248  ...  7.846607e-01  0.037439
#
# [5 rows x 28 columns]

# %%
#Load data from Piscultura
from google.colab import files
uploaded2 = files.upload() #choose file dados_relativizados_centralizados_piscicultura.csv
# Out:
#      <input type="file" id="files-6a62ae63-f9d2-4235-9fa3-856690361b80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a62ae63-f9d2-4235-9fa3-856690361b80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_piscicultura.csv to dados_relativizados_centralizados_piscicultura.csv

# %%
#Upload data from cvs file
df2 = pd.read_csv(io.StringIO(uploaded2['dados_relativizados_centralizados_piscicultura.csv'].decode('utf-8'))) 
#print(df2)

column_names = df2.columns
#Select fatores Economicos e Ambientais
feature_names = [name for name in column_names if( name.startswith("E") | name.startswith("A")) ] 

list_names = ['cultivo'] + feature_names
df_cultivo_2 = df2[list_names]
df_cultivo_2.head()
# Out:
#                                              cultivo  ...        A4_EUC
# 0                                   Truta - race-way  ... -1.015822e+00
# 1  Tilapia - gaiolas - SP -  sem restricao alimentar  ...  1.597613e+00
# 2   Tilapia - gaiolas - SP - com restricao alimentar  ...  2.078678e+00
# 3                              Tilapia - gaiola - RS  ...  3.150000e-16
# 4                             Tambatinga - viveiro 2  ...  3.150000e-16
#
# [5 rows x 21 columns]

# %%
#Merge only rows that have the same column names
df_cultivo = pd.concat([df_cultivo_1, df_cultivo_2], axis=0, join="inner",ignore_index=True)
print(df_cultivo.columns)
#combined_df.dropna(axis=1)
#print(combined_df["S7_PA"])
df_cultivo
# Out:
# Index(['cultivo', 'E1_RRLII', 'E2_TIR', 'E3_PRC', 'E4_RBC', 'E5_VPL', 'E6_LL',
#        'E9_R', 'E11_TR', 'E12_DP', 'E13_DM', 'A2_DA', 'A3_UE', 'A5_UN',
#        'A6_UF', 'A7_EUE', 'A8_EUN', 'A9_EUF', 'A12_PPO', 'A22_REC', 'A4_EUC'],
#       dtype='object')
#                                               cultivo  ...        A4_EUC
# 0                    M. rosenbergii - Espirito Santo-  ... -3.354904e+00
# 1              P. vannamei - Sergipe - Semi intensivo  ...  9.909967e-01
# 2                              L. vannamei - Aquafort  ...  3.228792e-01
# 3                              L. vannamei - Northern  ...  7.194307e-02
# 4                            L. vannamei - Aquacrusta  ...  3.743935e-02
# 5                                    L. vannamei - HM  ...  2.444617e-01
# 6                                  L. vannamei - Ilha  ...  4.483473e-01
# 7                               L. vannamei - Carpixe  ...  5.312286e-02
# 8                               L. vannamei - Marinus  ...  5.173547e-01
# 9                          L. vannamei - Aquabrasilis  ...  1.629074e-01
# 10             L. vannamei - Aquarium - baixa densid.  ...  1.440872e-01
# 11               L. vannamei - Aquarium - alta densis  ...  1.179480e-01
# 12                  L. vannamei - Aquarium-  bifasico  ...  2.434161e-01
# 13                                   Truta - race-way  ... -1.015822e+00
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...  1.597613e+00
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...  2.078678e+00
# 16                              Tilapia - gaiola - RS  ...  3.150000e-16
# 17                             Tambatinga - viveiro 2  ...  3.150000e-16
# 18                            Tambatinga - viveiro 23  ...  3.150000e-16
# 19                           Tambatinga - viveiro 250  ...  3.150000e-16
# 20         Tambaqui - M amazonicum - policultivo - SP  ... -6.273914e-02
# 21                         Tilapia - tanque rede - RN  ...  3.150000e-16
# 22          Lambari - semi intensivo - baixo controle  ...  1.768146e-01
# 23          Lambari - semi intensivo - médio controle  ... -1.711763e+00
# 24           Lambari - semi intensivo - alto controle  ... -1.062781e+00
#
# [25 rows x 21 columns]

# %%
#Look at correlations 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

corr = df_cultivo.corr()

# using a styled panda's dataframe from https://stackoverflow.com/a/42323184/1215012
cmap = 'coolwarm'

def magnify():
    return [dict(selector="th", props=[("font-size", "7pt")]),
            dict(selector="td", props=[('padding', "0em 0em")]),
            dict(selector="th:hover", props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover", 
                 props=[('max-width', '200px'), ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style  type="text/css" >
#     #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002 th {
#           font-size: 7pt;
#     }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002 td {
#           padding: 0em 0em;
#     }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002 th:hover {
#           font-size: 12pt;
#     }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col1 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col2 {
#             background-color:  #adc9fd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col3 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col5 {
#             background-color:  #f7a688;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col6 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col7 {
#             background-color:  #7a9df8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col8 {
#             background-color:  #89acfd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col9 {
#             background-color:  #5a78e4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col10 {
#             background-color:  #6b8df0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col11 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col12 {
#             background-color:  #84a7fc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col14 {
#             background-color:  #6687ed;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col15 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col16 {
#             background-color:  #9abbff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col17 {
#             background-color:  #f6bea4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col18 {
#             background-color:  #688aef;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row0_col19 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col2 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col3 {
#             background-color:  #cfdaea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col4 {
#             background-color:  #f7a98b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col5 {
#             background-color:  #f18d6f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col6 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col7 {
#             background-color:  #7295f4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col8 {
#             background-color:  #93b5fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col9 {
#             background-color:  #afcafc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col10 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col12 {
#             background-color:  #dedcdb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col14 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col15 {
#             background-color:  #f59d7e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col16 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col17 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col18 {
#             background-color:  #536edd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_b73f37c0_dfef_11ea_b6a0_0242ac1c0002row1_col19 {

# %%
#smaller chart
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='coolwarm')

# %%
#check which ones are statiscally significant
from scipy.stats import pearsonr
import pandas as pd

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

p_values = calculate_pvalues(df_cultivo)

# %%
#Plot p-values
def highlight_significant(val):
    '''
    highlight in blue only the statistically significant cells
    '''
    color = 'blue' if val < 0.05 else 'grey'
    return 'color: %s' % color

p_values.style.applymap(highlight_significant)
# Out:
# <style  type="text/css" >
#     #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col0 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col1 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col2 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col3 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col4 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col5 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col6 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col7 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col8 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col9 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col10 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col11 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col12 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col13 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col14 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col15 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col16 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col17 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col18 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row0_col19 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col0 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col1 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col2 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col3 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col4 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col5 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col6 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col7 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col8 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col9 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col10 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col11 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col12 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col13 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col14 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col15 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col16 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col17 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col18 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row1_col19 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col0 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col1 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col2 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col3 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col4 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col5 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col6 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col7 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col8 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col9 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col10 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col11 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col12 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col13 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col14 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col15 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col16 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col17 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col18 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row2_col19 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col0 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col1 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col2 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col3 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col4 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col5 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col6 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col7 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col8 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col9 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col10 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col11 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col12 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col13 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col14 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col15 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col16 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col17 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col18 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row3_col19 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col0 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col1 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col2 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col3 {
#             color:  grey;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col4 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col5 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col6 {
#             color:  blue;
#         }    #T_bf99b95e_dfef_11ea_b6a0_0242ac1c0002row4_col7 {
#             color:  grey;
#         }    #T_bf99b95

# %%
#Smaller plot of p-values
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

np.random.seed(101)
zvals = np.random.rand(100, 100) * 10

# make a color map of fixed colors
cmap_discrete = colors.ListedColormap(['lightblue', 'white'])
bounds=[0,0.05,1]
norm_binary = colors.BoundaryNorm(bounds, cmap_discrete.N)

# tell imshow about color map so that only set colors are used
img = plt.imshow(zvals, interpolation='nearest', origin='lower',
                    cmap=cmap_discrete, norm=norm_binary)

sns.heatmap(p_values, xticklabels=p_values.columns, yticklabels=p_values.columns, cmap=cmap_discrete, norm=norm_binary)

# %% [markdown]
# **PCA**
# Now we do the PCA

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)
x.shape
# Out:
# (25, 20)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

df_components = pd.DataFrame(data = principalComponents
            , columns = ['principal component 1', 'principal component 2'])

df_components = pd.concat([df_cultivo['cultivo'],df_components], axis = 1)

# %%
#Visualize results of PCA in Two Dimensions
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()
print(targets)
for target in targets:
    indicesToKeep = df_components['cultivo'] == target
    x = df_components.loc[indicesToKeep, 'principal component 1']
    y = df_components.loc[indicesToKeep, 'principal component 2']
    ax.scatter(x,y,s = 100)
    ax.annotate(target, (x,y))

#for name in targets:  
    
ax.legend(targets)
ax.grid()
# Out:
# ['M. rosenbergii - Espirito Santo-'
#  'P. vannamei - Sergipe - Semi intensivo' 'L. vannamei - Aquafort'
#  'L. vannamei - Northern' 'L. vannamei - Aquacrusta' 'L. vannamei - HM'
#  'L. vannamei - Ilha' 'L. vannamei - Carpixe' 'L. vannamei - Marinus'
#  'L. vannamei - Aquabrasilis' 'L. vannamei - Aquarium - baixa densid.'
#  'L. vannamei - Aquarium - alta densis'
#  'L. vannamei - Aquarium-  bifasico' 'Truta - race-way'
#  'Tilapia - gaiolas - SP -  sem restricao alimentar'
#  'Tilapia - gaiolas - SP - com restricao alimentar'
#  'Tilapia - gaiola - RS' 'Tambatinga - viveiro 2'
#  'Tambatinga - viveiro 23' 'Tambatinga - viveiro 250'
#  'Tambaqui - M amazonicum - policultivo - SP' 'Tilapia - tanque rede - RN'
#  'Lambari - semi intensivo - baixo controle'
#  'Lambari - semi intensivo - médio controle'
#  'Lambari - semi intensivo - alto controle']

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.28876724 0.1681934 ]
# total variance explained: 0.4569606347919187

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1])}, columns=['cultivo', 'pc1','pc2'])
#df_clustering

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 1              P. vannamei - Sergipe - Semi intensivo  ...        0
# 9                          L. vannamei - Aquabrasilis  ...        0
# 8                               L. vannamei - Marinus  ...        1
# 13                                   Truta - race-way  ...        1
# 23          Lambari - semi intensivo - médio controle  ...        1
# 18                            Tambatinga - viveiro 23  ...        1
# 19                           Tambatinga - viveiro 250  ...        1
# 17                             Tambatinga - viveiro 2  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 4                            L. vannamei - Aquacrusta  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 21                         Tilapia - tanque rede - RN  ...        3
# 22          Lambari - semi intensivo - baixo controle  ...        3
# 0                    M. rosenbergii - Espirito Santo-  ...        3
# 12                  L. vannamei - Aquarium-  bifasico  ...        3
# 11               L. vannamei - Aquarium - alta densis  ...        3
# 10             L. vannamei - Aquarium - baixa densid.  ...        3
# 5                                    L. vannamei - HM  ...        3
# 3                              L. vannamei - Northern  ...        3
# 2                              L. vannamei - Aquafort  ...        3
# 16                              Tilapia - gaiola - RS  ...        3
# 24           Lambari - semi intensivo - alto controle  ...        3
#
# [25 rows x 4 columns]

# %%
#5 clusters
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50,  marker='x', color="red"); # Show the

# %% [markdown]
# In my view, we have two large clusters and three outliers, as the graph above shows.

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 19                           Tambatinga - viveiro 250  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 18                            Tambatinga - viveiro 23  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 0                    M. rosenbergii - Espirito Santo-  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        1
# 21                         Tilapia - tanque rede - RN  ...        1
# 16                              Tilapia - gaiola - RS  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 5                                    L. vannamei - HM  ...        1
# 3                              L. vannamei - Northern  ...        1
# 2                              L. vannamei - Aquafort  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 24           Lambari - semi intensivo - alto controle  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        3
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
# 8                               L. vannamei - Marinus  ...        4
# 13                                   Truta - race-way  ...        4
# 7                               L. vannamei - Carpixe  ...        4
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        4
#
# [25 rows x 4 columns]

# %%
#6 clusters
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the 

#7 clusters

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 13                                   Truta - race-way  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 19                           Tambatinga - viveiro 250  ...        3
# 18                            Tambatinga - viveiro 23  ...        3
# 1              P. vannamei - Sergipe - Semi intensivo  ...        4
# 9                          L. vannamei - Aquabrasilis  ...        4
# 22          Lambari - semi intensivo - baixo controle  ...        5
# 21                         Tilapia - tanque rede - RN  ...        5
# 17                             Tambatinga - viveiro 2  ...        5
# 0                    M. rosenbergii - Espirito Santo-  ...        5
# 23          Lambari - semi intensivo - médio controle  ...        5
# 6                                  L. vannamei - Ilha  ...        5
# 5                                    L. vannamei - HM  ...        5
# 4                            L. vannamei - Aquacrusta  ...        5
# 3                              L. vannamei - Northern  ...        5
# 2                              L. vannamei - Aquafort  ...        5
# 16                              Tilapia - gaiola - RS  ...        5
# 24           Lambari - semi intensivo - alto controle  ...        5
#
# [25 rows x 4 columns]

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 13                                   Truta - race-way  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 19                           Tambatinga - viveiro 250  ...        3
# 18                            Tambatinga - viveiro 23  ...        3
# 1              P. vannamei - Sergipe - Semi intensivo  ...        4
# 9                          L. vannamei - Aquabrasilis  ...        4
# 22          Lambari - semi intensivo - baixo controle  ...        5
# 21                         Tilapia - tanque rede - RN  ...        5
# 17                             Tambatinga - viveiro 2  ...        5
# 0                    M. rosenbergii - Espirito Santo-  ...        5
# 23          Lambari - semi intensivo - médio controle  ...        5
# 6                                  L. vannamei - Ilha  ...        5
# 5                                    L. vannamei - HM  ...        5
# 4                            L. vannamei - Aquacrusta  ...        5
# 3                              L. vannamei - Northern  ...        5
# 2                              L. vannamei - Aquafort  ...        5
# 16                              Tilapia - gaiola - RS  ...        5
# 24           Lambari - semi intensivo - alto controle  ...        5
#
# [25 rows x 4 columns]

# %% [markdown]
# Now we analyze 3 Principal Components

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
finalDf = pd.concat([principalDf, df_cultivo[['cultivo']]], axis = 1)

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])}, columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#Visualize results of PCA in Three Dimensions
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    
ax.legend(targets)
ax.grid()

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.28876724 0.1681934  0.11875783]
# total variance explained: 0.5757184688862264

# %% [markdown]
# Now we search for clusters for 3 principal components

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
   
ax.legend(targets)
ax.grid()

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]),
                              'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])},
                              columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 18                            Tambatinga - viveiro 23  ...        0
# 19                           Tambatinga - viveiro 250  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 3                              L. vannamei - Northern  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 5                                    L. vannamei - HM  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 7                               L. vannamei - Carpixe  ...        1
# 9                          L. vannamei - Aquabrasilis  ...        1
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 13                                   Truta - race-way  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        2
# 21                         Tilapia - tanque rede - RN  ...        2
# 12                  L. vannamei - Aquarium-  bifasico  ...        2
# 23          Lambari - semi intensivo - médio controle  ...        2
# 11               L. vannamei - Aquarium - alta densis  ...        2
# 10             L. vannamei - Aquarium - baixa densid.  ...        2
# 24           Lambari - semi intensivo - alto controle  ...        2
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        3
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        3
#
# [25 rows x 5 columns]

# %% [markdown]
# Comparing k-means of PC12 with PC123, we see that the cluster membership changes completely.

# %%
#5 clusters 
from sklearn.cluster import KMeans
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    #ax.annotate(target, (x,y))

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 

#for name in targets:  
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        0
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        0
# 0                    M. rosenbergii - Espirito Santo-  ...        1
# 17                             Tambatinga - viveiro 2  ...        1
# 2                              L. vannamei - Aquafort  ...        1
# 3                              L. vannamei - Northern  ...        1
# 4                            L. vannamei - Aquacrusta  ...        1
# 5                                    L. vannamei - HM  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 16                              Tilapia - gaiola - RS  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        1
# 13                                   Truta - race-way  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 7                               L. vannamei - Carpixe  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        2
# 18                            Tambatinga - viveiro 23  ...        3
# 19                           Tambatinga - viveiro 250  ...        3
# 21                         Tilapia - tanque rede - RN  ...        4
# 12                  L. vannamei - Aquarium-  bifasico  ...        4
# 11               L. vannamei - Aquarium - alta densis  ...        4
# 10             L. vannamei - Aquarium - baixa densid.  ...        4
# 23          Lambari - semi intensivo - médio controle  ...        4
# 24           Lambari - semi intensivo - alto controle  ...        4
#
# [25 rows x 5 columns]

# %%
#6 clusters 
from sklearn.cluster import KMeans
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 5                                    L. vannamei - HM  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 1              P. vannamei - Sergipe - Semi intensivo  ...        1
# 9                          L. vannamei - Aquabrasilis  ...        1
# 21                         Tilapia - tanque rede - RN  ...        2
# 12                  L. vannamei - Aquarium-  bifasico  ...        2
# 11               L. vannamei - Aquarium - alta densis  ...        2
# 10             L. vannamei - Aquarium - baixa densid.  ...        2
# 23          Lambari - semi intensivo - médio controle  ...        2
# 24           Lambari - semi intensivo - alto controle  ...        2
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        3
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        3
# 18                            Tambatinga - viveiro 23  ...        4
# 19                           Tambatinga - viveiro 250  ...        4
# 13                                   Truta - race-way  ...        5
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        5
# 8                               L. vannamei - Marinus  ...        5
# 7                               L. vannamei - Carpixe  ...        5
#
# [25 rows x 5 columns]
