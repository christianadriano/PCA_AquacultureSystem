# %% [markdown]
# <a href="https://colab.research.google.com/github/christianadriano/PCA_AquacultureSystem/blob/master/PCA_KMeans_All_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tables for data wrangling
import numpy as np #basic statistical methods 
import io #for uploading data

#Manual option
from google.colab import files
uploaded1 = files.upload() #choose file dados_relativizados_carcinicultura.csv
# Out:
#      <input type="file" id="files-ef8173e6-0dae-478d-ab2f-bb9c523942f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef8173e6-0dae-478d-ab2f-bb9c523942f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_carcinicultura.csv to dados_relativizados_centralizados_carcinicultura.csv

# %%
#Upload data from cvs file
df1 = pd.read_csv(io.StringIO(uploaded1['dados_relativizados_centralizados_carcinicultura.csv'].decode('utf-8'))) 
print(df1)
# Out:
#     Unnamed: 0         cultura  ...    S19_IR    S20_IE
# 0            0  Carcinicultura  ... -0.015126 -0.181345
# 1            1  Carcinicultura  ... -3.007332  1.033912
# 2            2  Carcinicultura  ...  0.028468 -1.738392
# 3            3  Carcinicultura  ...  0.168525 -0.540663
# 4            4  Carcinicultura  ...  0.038207 -0.549427
# 5            5  Carcinicultura  ...  0.245973 -0.540663
# 6            6  Carcinicultura  ...  0.068815  1.393230
# 7            7  Carcinicultura  ... -0.217791 -0.937959
# 8            8  Carcinicultura  ... -0.385673 -1.043125
# 9            9  Carcinicultura  ... -0.217791  1.895692
# 10          10  Carcinicultura  ...  1.097908  0.402913
# 11          11  Carcinicultura  ...  1.097908  0.402913
# 12          12  Carcinicultura  ...  1.097908  0.402913
#
# [13 rows x 50 columns]

# %%
column_names = df1.columns
#Select fatores Sociais, Ambientais, Economicos 
feature_names = [name for name in column_names if (name.startswith("S")|name.startswith("E")|name.startswith("A"))] 

#feature_names = list(df.columns["E1_RRLII":"E13_DM"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo_1 = df1[list_names]
df_cultivo_1.head()
# Out:
#                                   cultivo  E1_RRLII  ...    S19_IR    S20_IE
# 0        M. rosenbergii - Espirito Santo- -0.942112  ... -0.015126 -0.181345
# 1  P. vannamei - Sergipe - Semi intensivo  2.444167  ... -3.007332  1.033912
# 2                  L. vannamei - Aquafort -0.777345  ...  0.028468 -1.738392
# 3                  L. vannamei - Northern -0.738076  ...  0.168525 -0.540663
# 4                L. vannamei - Aquacrusta -0.213248  ...  0.038207 -0.549427
#
# [5 rows x 47 columns]

# %%
#Load data from Piscultura
from google.colab import files
uploaded2 = files.upload() #choose file dados_relativizados_centralizados_piscicultura.csv
# Out:
#      <input type="file" id="files-98bbe474-620a-479d-8be2-8f138ac4d7cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98bbe474-620a-479d-8be2-8f138ac4d7cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_piscicultura.csv to dados_relativizados_centralizados_piscicultura.csv

# %%
#Upload data from cvs file
df2 = pd.read_csv(io.StringIO(uploaded2['dados_relativizados_centralizados_piscicultura.csv'].decode('utf-8'))) 
#print(df2)

column_names = df2.columns
#Select fatores Sociais, Ambientais, Economicos 
feature_names = [name for name in column_names if (name.startswith("S")|name.startswith("E")|name.startswith("A"))] 

#feature_names = list(df.columns["E1_RRLII":"E13_DM"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo_2 = df2[list_names]
df_cultivo_2.head()
# Out:
#                                              cultivo  ...        S20_IE
# 0                                   Truta - race-way  ...  5.807265e-01
# 1  Tilapia - gaiolas - SP -  sem restricao alimentar  ... -1.060000e-10
# 2   Tilapia - gaiolas - SP - com restricao alimentar  ... -1.060000e-10
# 3                              Tilapia - gaiola - RS  ... -1.060000e-10
# 4                             Tambatinga - viveiro 2  ... -1.011749e+00
#
# [5 rows x 34 columns]

# %%
#Merge only rows that have the same column names
df_cultivo = pd.concat([df_cultivo_1, df_cultivo_2], axis=0, join="inner",ignore_index=True)
print(df_cultivo.columns)
#combined_df.dropna(axis=1)
#print(combined_df["S7_PA"])
df_cultivo
# Out:
# Index(['cultivo', 'E1_RRLII', 'E2_TIR', 'E3_PRC', 'E4_RBC', 'E5_VPL', 'E6_LL',
#        'E9_R', 'E11_TR', 'E12_DP', 'E13_DM', 'A2_DA', 'A3_UE', 'A5_UN',
#        'A6_UF', 'A7_EUE', 'A8_EUN', 'A9_EUF', 'A12_PPO', 'A22_REC', 'A4_EUC',
#        'S1_DEL', 'S2_UMOL', 'S3_RTUP', 'S6_PA', 'S8_TRUAO', 'S9_TRUP',
#        'S10_SLT', 'S11_CLP', 'S13_CPT', 'S14_DR', 'S18_IG', 'S19_IR',
#        'S20_IE'],
#       dtype='object')
#                                               cultivo  ...        S20_IE
# 0                    M. rosenbergii - Espirito Santo-  ... -1.813446e-01
# 1              P. vannamei - Sergipe - Semi intensivo  ...  1.033912e+00
# 2                              L. vannamei - Aquafort  ... -1.738392e+00
# 3                              L. vannamei - Northern  ... -5.406632e-01
# 4                            L. vannamei - Aquacrusta  ... -5.494271e-01
# 5                                    L. vannamei - HM  ... -5.406632e-01
# 6                                  L. vannamei - Ilha  ...  1.393230e+00
# 7                               L. vannamei - Carpixe  ... -9.379585e-01
# 8                               L. vannamei - Marinus  ... -1.043125e+00
# 9                          L. vannamei - Aquabrasilis  ...  1.895692e+00
# 10             L. vannamei - Aquarium - baixa densid.  ...  4.029132e-01
# 11               L. vannamei - Aquarium - alta densis  ...  4.029132e-01
# 12                  L. vannamei - Aquarium-  bifasico  ...  4.029132e-01
# 13                                   Truta - race-way  ...  5.807265e-01
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ... -1.060000e-10
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ... -1.060000e-10
# 16                              Tilapia - gaiola - RS  ... -1.060000e-10
# 17                             Tambatinga - viveiro 2  ... -1.011749e+00
# 18                            Tambatinga - viveiro 23  ... -1.009361e+00
# 19                           Tambatinga - viveiro 250  ... -1.001854e+00
# 20         Tambaqui - M amazonicum - policultivo - SP  ... -1.060000e-10
# 21                         Tilapia - tanque rede - RN  ...  2.816735e+00
# 22          Lambari - semi intensivo - baixo controle  ... -7.313371e-01
# 23          Lambari - semi intensivo - médio controle  ... -2.662038e-02
# 24           Lambari - semi intensivo - alto controle  ...  3.834602e-01
#
# [25 rows x 34 columns]

# %%
#Look at correlations 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

corr = df_cultivo.corr()

# using a styled panda's dataframe from https://stackoverflow.com/a/42323184/1215012
cmap = 'coolwarm'

def magnify():
    return [dict(selector="th", props=[("font-size", "7pt")]),
            dict(selector="td", props=[('padding', "0em 0em")]),
            dict(selector="th:hover", props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover", 
                 props=[('max-width', '200px'), ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style  type="text/css" >
#     #T_342b66fe_f5a4_11ea_a015_0242ac1c0002 th {
#           font-size: 7pt;
#     }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002 td {
#           padding: 0em 0em;
#     }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002 th:hover {
#           font-size: 12pt;
#     }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col3 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col4 {
#             background-color:  #f7a688;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col5 {
#             background-color:  #f18f71;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col6 {
#             background-color:  #edd1c2;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col8 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col9 {
#             background-color:  #9bbcff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col10 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col11 {
#             background-color:  #82a6fb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col12 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col13 {
#             background-color:  #7da0f9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col14 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col15 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col16 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col17 {
#             background-color:  #f6a586;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col18 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col19 {
#             background-color:  #d1dae9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col20 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col21 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col22 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col23 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col24 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col25 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col26 {
#             background-color:  #96b7ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col27 {
#             background-color:  #92b4fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col28 {
#             background-color:  #dadce0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col29 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col30 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col31 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row0_col32 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col2 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col3 {
#             background-color:  #cfdaea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col4 {
#             background-color:  #f7a98b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col5 {
#             background-color:  #f18d6f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_342b66fe_f5a4_11ea_a015_0242ac1c0002row1_col

# %%
#smaller chart
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
#sns.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)
htmap = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='coolwarm',ax=ax,linewidths=.5)

# %%
htmap.get_figure().savefig("smallerPlot-correlations_TodosIndicadores.png")

# %%
#check which ones are statiscally significant
from scipy.stats import pearsonr
import pandas as pd

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

p_values = calculate_pvalues(df_cultivo)

# %%
#Plot p-values
def highlight_significant(val):
    '''
    highlight in blue only the statistically significant cells
    '''
    color = 'blue' if val < 0.05 else 'grey'
    return 'color: %s' % color

p_values.style.applymap(highlight_significant)
# Out:
# <style  type="text/css" >
#     #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col0 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col1 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col2 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col3 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col4 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col5 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col6 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col7 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col8 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col9 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col10 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col11 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col12 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col13 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col14 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col15 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col16 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col17 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col18 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col19 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col20 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col21 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col22 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col23 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col24 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col25 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col26 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col27 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col28 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col29 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col30 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col31 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row0_col32 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col0 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col1 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col2 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col3 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col4 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col5 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col6 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col7 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col8 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col9 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col10 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col11 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col12 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col13 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col14 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col15 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col16 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col17 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col18 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col19 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col20 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col21 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col22 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col23 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col24 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col25 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col26 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col27 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col28 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col29 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col30 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col31 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row1_col32 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col0 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col1 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col2 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col3 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col4 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col5 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col6 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col7 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col8 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col9 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col10 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col11 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col12 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col13 {
#             color:  blue;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col14 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col15 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col16 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col17 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col18 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col19 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col20 {
#             color:  grey;
#         }    #T_84b80698_f5a6_11ea_a015_0242ac1c0002row2_col21 {
#             color:  blue;

# %%
#Smaller plot of p-values
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

np.random.seed(101)
zvals = np.random.rand(100, 100) * 10

# make a color map of fixed colors
cmap_discrete = colors.ListedColormap(['blue', 'lightgrey'])
bounds=[0,0.05,1]
norm_binary = colors.BoundaryNorm(bounds, cmap_discrete.N)

# tell imshow about color map so that only set colors are used
#plt.imshow(zvals, interpolation='nearest', origin='lower',
#                    cmap=cmap_discrete, norm=norm_binary) 

fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
htmap_pvalues= sns.heatmap(p_values, xticklabels=p_values.columns, yticklabels=p_values.columns, cmap=cmap_discrete, norm=norm_binary, ax=ax,linewidths=0.5)

# %%
#save heatmap to file
htmap_pvalues.get_figure().savefig("smallerPlot_pvalues-of-correlations-TodosIndicadores.png")

# %% [markdown]
# **PCA**
# Now we do the PCA

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)
x.shape
# Out:
# (25, 33)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

df_components = pd.DataFrame(data = principalComponents
            , columns = ['principal component 1', 'principal component 2'])

df_components = pd.concat([df_cultivo['cultivo'],df_components], axis = 1)

# %%
#Visualize results of PCA in Two Dimensions
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()
print(targets)
for target in targets:
    indicesToKeep = df_components['cultivo'] == target
    x = df_components.loc[indicesToKeep, 'principal component 1']
    y = df_components.loc[indicesToKeep, 'principal component 2']
    ax.scatter(x,y,s = 100)
    ax.annotate(target, (x,y))

#for name in targets:  
    
ax.legend(targets)
ax.grid()
# Out:
# ['M. rosenbergii - Espirito Santo-'
#  'P. vannamei - Sergipe - Semi intensivo' 'L. vannamei - Aquafort'
#  'L. vannamei - Northern' 'L. vannamei - Aquacrusta' 'L. vannamei - HM'
#  'L. vannamei - Ilha' 'L. vannamei - Carpixe' 'L. vannamei - Marinus'
#  'L. vannamei - Aquabrasilis' 'L. vannamei - Aquarium - baixa densid.'
#  'L. vannamei - Aquarium - alta densis'
#  'L. vannamei - Aquarium-  bifasico' 'Truta - race-way'
#  'Tilapia - gaiolas - SP -  sem restricao alimentar'
#  'Tilapia - gaiolas - SP - com restricao alimentar'
#  'Tilapia - gaiola - RS' 'Tambatinga - viveiro 2'
#  'Tambatinga - viveiro 23' 'Tambatinga - viveiro 250'
#  'Tambaqui - M amazonicum - policultivo - SP' 'Tilapia - tanque rede - RN'
#  'Lambari - semi intensivo - baixo controle'
#  'Lambari - semi intensivo - médio controle'
#  'Lambari - semi intensivo - alto controle']

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.21262711 0.15155054]
# total variance explained: 0.36417764954919096

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1])}, columns=['cultivo', 'pc1','pc2'])
#df_clustering

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 7                               L. vannamei - Carpixe  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 9                          L. vannamei - Aquabrasilis  ...        0
# 13                                   Truta - race-way  ...        0
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        0
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        0
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 21                         Tilapia - tanque rede - RN  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        2
# 19                           Tambatinga - viveiro 250  ...        2
# 18                            Tambatinga - viveiro 23  ...        2
# 17                             Tambatinga - viveiro 2  ...        2
# 0                    M. rosenbergii - Espirito Santo-  ...        2
# 23          Lambari - semi intensivo - médio controle  ...        2
# 5                                    L. vannamei - HM  ...        2
# 4                            L. vannamei - Aquacrusta  ...        2
# 3                              L. vannamei - Northern  ...        2
# 2                              L. vannamei - Aquafort  ...        2
# 16                              Tilapia - gaiola - RS  ...        2
# 24           Lambari - semi intensivo - alto controle  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
#
# [25 rows x 4 columns]

# %%
#5 clusters
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50,  marker='x', color="red"); # Show the

# %% [markdown]
# In my view, we have two large clusters and three outliers, as the graph above shows.

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 18                            Tambatinga - viveiro 23  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 5                                    L. vannamei - HM  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 19                           Tambatinga - viveiro 250  ...        0
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 21                         Tilapia - tanque rede - RN  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 8                               L. vannamei - Marinus  ...        2
# 13                                   Truta - race-way  ...        2
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 7                               L. vannamei - Carpixe  ...        2
# 6                                  L. vannamei - Ilha  ...        2
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
# 9                          L. vannamei - Aquabrasilis  ...        3
# 22          Lambari - semi intensivo - baixo controle  ...        4
# 0                    M. rosenbergii - Espirito Santo-  ...        4
# 23          Lambari - semi intensivo - médio controle  ...        4
# 16                              Tilapia - gaiola - RS  ...        4
# 24           Lambari - semi intensivo - alto controle  ...        4
#
# [25 rows x 4 columns]

# %%
#6 clusters
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the 

#7 clusters

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 21                         Tilapia - tanque rede - RN  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        2
# 16                              Tilapia - gaiola - RS  ...        2
# 0                    M. rosenbergii - Espirito Santo-  ...        2
# 5                                    L. vannamei - HM  ...        2
# 3                              L. vannamei - Northern  ...        2
# 23          Lambari - semi intensivo - médio controle  ...        2
# 24           Lambari - semi intensivo - alto controle  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
# 13                                   Truta - race-way  ...        4
# 9                          L. vannamei - Aquabrasilis  ...        4
# 4                            L. vannamei - Aquacrusta  ...        5
# 17                             Tambatinga - viveiro 2  ...        5
# 18                            Tambatinga - viveiro 23  ...        5
# 19                           Tambatinga - viveiro 250  ...        5
# 2                              L. vannamei - Aquafort  ...        5
#
# [25 rows x 4 columns]

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 21                         Tilapia - tanque rede - RN  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        1
# 22          Lambari - semi intensivo - baixo controle  ...        2
# 16                              Tilapia - gaiola - RS  ...        2
# 0                    M. rosenbergii - Espirito Santo-  ...        2
# 5                                    L. vannamei - HM  ...        2
# 3                              L. vannamei - Northern  ...        2
# 23          Lambari - semi intensivo - médio controle  ...        2
# 24           Lambari - semi intensivo - alto controle  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
# 13                                   Truta - race-way  ...        4
# 9                          L. vannamei - Aquabrasilis  ...        4
# 4                            L. vannamei - Aquacrusta  ...        5
# 17                             Tambatinga - viveiro 2  ...        5
# 18                            Tambatinga - viveiro 23  ...        5
# 19                           Tambatinga - viveiro 250  ...        5
# 2                              L. vannamei - Aquafort  ...        5
#
# [25 rows x 4 columns]

# %% [markdown]
# Now we analyze 3 Principal Components

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
finalDf = pd.concat([principalDf, df_cultivo[['cultivo']]], axis = 1)

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])}, columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#Visualize results of PCA in Three Dimensions
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    
ax.legend(targets)
ax.grid()

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.21262711 0.15155054 0.13264894]
# total variance explained: 0.49682659251121264

# %% [markdown]
# Now we search for clusters for 3 principal components

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
   
ax.legend(targets)
ax.grid()

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]),
                              'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])},
                              columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        0
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        0
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 24           Lambari - semi intensivo - alto controle  ...        0
# 7                               L. vannamei - Carpixe  ...        1
# 2                              L. vannamei - Aquafort  ...        1
# 19                           Tambatinga - viveiro 250  ...        1
# 18                            Tambatinga - viveiro 23  ...        1
# 17                             Tambatinga - viveiro 2  ...        1
# 16                              Tilapia - gaiola - RS  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 3                              L. vannamei - Northern  ...        1
# 5                                    L. vannamei - HM  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 4                            L. vannamei - Aquacrusta  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        2
# 10             L. vannamei - Aquarium - baixa densid.  ...        2
# 21                         Tilapia - tanque rede - RN  ...        2
# 12                  L. vannamei - Aquarium-  bifasico  ...        2
# 13                                   Truta - race-way  ...        3
# 9                          L. vannamei - Aquabrasilis  ...        3
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
#
# [25 rows x 5 columns]

# %% [markdown]
# Comparing k-means of PC12 with PC123, we see that the cluster membership changes completely.

# %%
#5 clusters 
from sklearn.cluster import KMeans
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    #ax.annotate(target, (x,y))

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 

#for name in targets:  
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 24           Lambari - semi intensivo - alto controle  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 5                                    L. vannamei - HM  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 7                               L. vannamei - Carpixe  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 19                           Tambatinga - viveiro 250  ...        0
# 18                            Tambatinga - viveiro 23  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 21                         Tilapia - tanque rede - RN  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 13                                   Truta - race-way  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 0                    M. rosenbergii - Espirito Santo-  ...        3
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        4
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        4
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        4
#
# [25 rows x 5 columns]

# %%
#6 clusters 
from sklearn.cluster import KMeans
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 24           Lambari - semi intensivo - alto controle  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 5                                    L. vannamei - HM  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 7                               L. vannamei - Carpixe  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 19                           Tambatinga - viveiro 250  ...        0
# 18                            Tambatinga - viveiro 23  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 21                         Tilapia - tanque rede - RN  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        2
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        2
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        2
# 0                    M. rosenbergii - Espirito Santo-  ...        3
# 13                                   Truta - race-way  ...        4
# 9                          L. vannamei - Aquabrasilis  ...        4
# 1              P. vannamei - Sergipe - Semi intensivo  ...        5
#
# [25 rows x 5 columns]
