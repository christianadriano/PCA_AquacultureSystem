# %% [markdown]
# <a href="https://colab.research.google.com/github/christianadriano/PCA_AquacultureSystem/blob/master/CenterData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tables for data wrangling
import numpy as np #basic statistical methods 
import io #for uploading data

#Manual option
from google.colab import files
uploaded = files.upload() #choose file dados_relativizados_carcinicultura.csv
# Out:
#      <input type="file" id="files-9a02147e-8c9a-42c7-a146-83742b310e07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a02147e-8c9a-42c7-a146-83742b310e07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_carcinicultura.csv to dados_relativizados_carcinicultura (1).csv

# %%
df = pd.read_csv(io.StringIO(uploaded['dados_relativizados_carcinicultura.csv'].decode('utf-8'))) 
df.shape
#print(df)
# Out:
# (13, 49)

# %%
#Center the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df.iloc[:,3:].values
x = StandardScaler().fit_transform(x) # normalizing the features
df_x = pd.DataFrame(x)
df_x.mean()

# %%
df_centered = pd.concat([df[['cultura']],df[['cultivo']],df[['fazenda']],df_x], axis = 1)
df_centered.columns = df.columns
# Out:
#            cultura                                 cultivo  ...    S19_IR    S20_IE
# 0   Carcinicultura        M. rosenbergii - Espirito Santo-  ... -0.015126 -0.181345
# 1   Carcinicultura  P. vannamei - Sergipe - Semi intensivo  ... -3.007332  1.033912
# 2   Carcinicultura                  L. vannamei - Aquafort  ...  0.028468 -1.738392
# 3   Carcinicultura                  L. vannamei - Northern  ...  0.168525 -0.540663
# 4   Carcinicultura                L. vannamei - Aquacrusta  ...  0.038207 -0.549427
# 5   Carcinicultura                        L. vannamei - HM  ...  0.245973 -0.540663
# 6   Carcinicultura                      L. vannamei - Ilha  ...  0.068815  1.393230
# 7   Carcinicultura                   L. vannamei - Carpixe  ... -0.217791 -0.937959
# 8   Carcinicultura                   L. vannamei - Marinus  ... -0.385673 -1.043125
# 9   Carcinicultura              L. vannamei - Aquabrasilis  ... -0.217791  1.895692
# 10  Carcinicultura  L. vannamei - Aquarium - baixa densid.  ...  1.097908  0.402913
# 11  Carcinicultura    L. vannamei - Aquarium - alta densis  ...  1.097908  0.402913
# 12  Carcinicultura       L. vannamei - Aquarium-  bifasico  ...  1.097908  0.402913
#
# [13 rows x 49 columns]
