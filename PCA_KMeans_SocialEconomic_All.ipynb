# %% [markdown]
# <a href="https://colab.research.google.com/github/christianadriano/PCA_AquacultureSystem/blob/master/PCA_KMeans_SocialEconomic_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tables for data wrangling
import numpy as np #basic statistical methods 
import io #for uploading data

#Manual option
from google.colab import files
uploaded1 = files.upload() #choose file dados_relativizados_carcinicultura.csv
# Out:
#      <input type="file" id="files-9cc7d8be-d292-4fb0-bfd6-37c7bdb2011d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cc7d8be-d292-4fb0-bfd6-37c7bdb2011d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_carcinicultura.csv to dados_relativizados_centralizados_carcinicultura.csv

# %%
#Upload data from cvs file
df1 = pd.read_csv(io.StringIO(uploaded1['dados_relativizados_centralizados_carcinicultura.csv'].decode('utf-8'))) 
print(df1)
# Out:
#     Unnamed: 0         cultura  ...    S19_IR    S20_IE
# 0            0  Carcinicultura  ... -0.015126 -0.181345
# 1            1  Carcinicultura  ... -3.007332  1.033912
# 2            2  Carcinicultura  ...  0.028468 -1.738392
# 3            3  Carcinicultura  ...  0.168525 -0.540663
# 4            4  Carcinicultura  ...  0.038207 -0.549427
# 5            5  Carcinicultura  ...  0.245973 -0.540663
# 6            6  Carcinicultura  ...  0.068815  1.393230
# 7            7  Carcinicultura  ... -0.217791 -0.937959
# 8            8  Carcinicultura  ... -0.385673 -1.043125
# 9            9  Carcinicultura  ... -0.217791  1.895692
# 10          10  Carcinicultura  ...  1.097908  0.402913
# 11          11  Carcinicultura  ...  1.097908  0.402913
# 12          12  Carcinicultura  ...  1.097908  0.402913
#
# [13 rows x 50 columns]

# %%
column_names = df1.columns
#Select fatores Sociais e Economicos
feature_names = [name for name in column_names if( name.startswith("S")|name.startswith("E"))] 

#feature_names = list(df.columns["E1_RRLII":"E13_DM"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo_1 = df1[list_names]
df_cultivo_1.head()
# Out:
#                                   cultivo  E1_RRLII  ...    S19_IR    S20_IE
# 0        M. rosenbergii - Espirito Santo- -0.942112  ... -0.015126 -0.181345
# 1  P. vannamei - Sergipe - Semi intensivo  2.444167  ... -3.007332  1.033912
# 2                  L. vannamei - Aquafort -0.777345  ...  0.028468 -1.738392
# 3                  L. vannamei - Northern -0.738076  ...  0.168525 -0.540663
# 4                L. vannamei - Aquacrusta -0.213248  ...  0.038207 -0.549427
#
# [5 rows x 31 columns]

# %%
#Load data from Piscultura
from google.colab import files
uploaded2 = files.upload() #choose file dados_relativizados_centralizados_piscicultura.csv
# Out:
#      <input type="file" id="files-edafd1ff-632b-4b5f-8a77-d946b236feca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edafd1ff-632b-4b5f-8a77-d946b236feca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dados_relativizados_centralizados_piscicultura.csv to dados_relativizados_centralizados_piscicultura.csv

# %%
#Upload data from cvs file
df2 = pd.read_csv(io.StringIO(uploaded2['dados_relativizados_centralizados_piscicultura.csv'].decode('utf-8'))) 
#print(df2)

column_names = df2.columns
#Select fatores Sociais e Economicos
feature_names = [name for name in column_names if( name.startswith("S")|name.startswith("E"))] 

#feature_names = list(df.columns["E1_RRLII":"E13_DM"])
#print(feature_names)
list_names = ['cultivo'] + feature_names
df_cultivo_2 = df2[list_names]
df_cultivo_2.head()
# Out:
#                                              cultivo  ...        S20_IE
# 0                                   Truta - race-way  ...  5.807265e-01
# 1  Tilapia - gaiolas - SP -  sem restricao alimentar  ... -1.060000e-10
# 2   Tilapia - gaiolas - SP - com restricao alimentar  ... -1.060000e-10
# 3                              Tilapia - gaiola - RS  ... -1.060000e-10
# 4                             Tambatinga - viveiro 2  ... -1.011749e+00
#
# [5 rows x 24 columns]

# %%
#Merge only rows that have the same column names
df_cultivo = pd.concat([df_cultivo_1, df_cultivo_2], axis=0, join="inner",ignore_index=True)
print(df_cultivo.columns)
df_cultivo
# Out:
# Index(['cultivo', 'E1_RRLII', 'E2_TIR', 'E3_PRC', 'E4_RBC', 'E5_VPL', 'E6_LL',
#        'E9_R', 'E11_TR', 'E12_DP', 'E13_DM', 'S1_DEL', 'S2_UMOL', 'S3_RTUP',
#        'S6_PA', 'S8_TRUAO', 'S9_TRUP', 'S10_SLT', 'S11_CLP', 'S13_CPT',
#        'S14_DR', 'S18_IG', 'S19_IR', 'S20_IE'],
#       dtype='object')
#                                               cultivo  ...        S20_IE
# 0                    M. rosenbergii - Espirito Santo-  ... -1.813446e-01
# 1              P. vannamei - Sergipe - Semi intensivo  ...  1.033912e+00
# 2                              L. vannamei - Aquafort  ... -1.738392e+00
# 3                              L. vannamei - Northern  ... -5.406632e-01
# 4                            L. vannamei - Aquacrusta  ... -5.494271e-01
# 5                                    L. vannamei - HM  ... -5.406632e-01
# 6                                  L. vannamei - Ilha  ...  1.393230e+00
# 7                               L. vannamei - Carpixe  ... -9.379585e-01
# 8                               L. vannamei - Marinus  ... -1.043125e+00
# 9                          L. vannamei - Aquabrasilis  ...  1.895692e+00
# 10             L. vannamei - Aquarium - baixa densid.  ...  4.029132e-01
# 11               L. vannamei - Aquarium - alta densis  ...  4.029132e-01
# 12                  L. vannamei - Aquarium-  bifasico  ...  4.029132e-01
# 13                                   Truta - race-way  ...  5.807265e-01
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ... -1.060000e-10
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ... -1.060000e-10
# 16                              Tilapia - gaiola - RS  ... -1.060000e-10
# 17                             Tambatinga - viveiro 2  ... -1.011749e+00
# 18                            Tambatinga - viveiro 23  ... -1.009361e+00
# 19                           Tambatinga - viveiro 250  ... -1.001854e+00
# 20         Tambaqui - M amazonicum - policultivo - SP  ... -1.060000e-10
# 21                         Tilapia - tanque rede - RN  ...  2.816735e+00
# 22          Lambari - semi intensivo - baixo controle  ... -7.313371e-01
# 23          Lambari - semi intensivo - médio controle  ... -2.662038e-02
# 24           Lambari - semi intensivo - alto controle  ...  3.834602e-01
#
# [25 rows x 24 columns]

# %%
#Look at correlations 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

corr = df_cultivo.corr()

# using a styled panda's dataframe from https://stackoverflow.com/a/42323184/1215012
cmap = 'coolwarm'

def magnify():
    return [dict(selector="th", props=[("font-size", "7pt")]),
            dict(selector="td", props=[('padding', "0em 0em")]),
            dict(selector="th:hover", props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover", 
                 props=[('max-width', '200px'), ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style  type="text/css" >
#     #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002 th {
#           font-size: 7pt;
#     }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002 td {
#           padding: 0em 0em;
#     }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002 th:hover {
#           font-size: 12pt;
#     }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col3 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col4 {
#             background-color:  #f7a688;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col5 {
#             background-color:  #f18f71;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col6 {
#             background-color:  #edd1c2;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col8 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col9 {
#             background-color:  #9bbcff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col10 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col11 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col12 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col13 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col14 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col15 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col16 {
#             background-color:  #96b7ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col17 {
#             background-color:  #92b4fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col18 {
#             background-color:  #dadce0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col19 {
#             background-color:  #d7dce3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col20 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row0_col22 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col0 {
#             background-color:  #f6a586;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col2 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col3 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col4 {
#             background-color:  #f7b396;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col5 {
#             background-color:  #f39577;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col6 {
#             background-color:  #d6dce4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col7 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col9 {
#             background-color:  #9dbdff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col10 {
#             background-color:  #8caffe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col11 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col12 {
#             background-color:  #adc9fd;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col13 {
#             background-color:  #aec9fc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col14 {
#             background-color:  #90b2fe;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col15 {
#             background-color:  #7699f6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_7755ba72_e0c5_11ea_98c9_0242ac1c0002row1_col16 {

# %%
#smaller chart
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='coolwarm')

# %%
#check which ones are statiscally significant
from scipy.stats import pearsonr
import pandas as pd

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

p_values = calculate_pvalues(df_cultivo)

# %%
#Plot p-values
def highlight_significant(val):
    '''
    highlight in blue only the statistically significant cells
    '''
    color = 'blue' if val < 0.05 else 'grey'
    return 'color: %s' % color

p_values.style.applymap(highlight_significant)
# Out:
# <style  type="text/css" >
#     #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col0 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col1 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col2 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col3 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col4 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col5 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col6 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col7 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col8 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col9 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col10 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col11 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col12 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col13 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col14 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col15 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col16 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col17 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col18 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col19 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col20 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col21 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row0_col22 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col0 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col1 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col2 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col3 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col4 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col5 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col6 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col7 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col8 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col9 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col10 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col11 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col12 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col13 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col14 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col15 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col16 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col17 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col18 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col19 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col20 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col21 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row1_col22 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col0 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col1 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col2 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col3 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col4 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col5 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col6 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col7 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col8 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col9 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col10 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col11 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col12 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col13 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col14 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col15 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col16 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col17 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col18 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col19 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col20 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col21 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row2_col22 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col0 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col1 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col2 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col3 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col4 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col5 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col6 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col7 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col8 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col9 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col10 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col11 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col12 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col13 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col14 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col15 {
#             color:  blue;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col16 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col17 {
#             color:  grey;
#         }    #T_7e526a32_e0c5_11ea_98c9_0242ac1c0002row3_col18 {
#             color:  grey;
#         }    #T

# %%
#Smaller plot of p-values
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

np.random.seed(101)
zvals = np.random.rand(100, 100) * 10

# make a color map of fixed colors
cmap_discrete = colors.ListedColormap(['lightblue', 'white'])
bounds=[0,0.05,1]
norm_binary = colors.BoundaryNorm(bounds, cmap_discrete.N)

# tell imshow about color map so that only set colors are used
img = plt.imshow(zvals, interpolation='nearest', origin='lower',
                    cmap=cmap_discrete, norm=norm_binary)

sns.heatmap(p_values, xticklabels=p_values.columns, yticklabels=p_values.columns, cmap=cmap_discrete, norm=norm_binary)

# %% [markdown]
# **PCA**
# Now we do the PCA

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)
x.shape
# Out:
# (25, 23)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

df_components = pd.DataFrame(data = principalComponents
            , columns = ['principal component 1', 'principal component 2'])

df_components = pd.concat([df_cultivo['cultivo'],df_components], axis = 1)

# %%
#Visualize results of PCA in Two Dimensions
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()
print(targets)
for target in targets:
    indicesToKeep = df_components['cultivo'] == target
    x = df_components.loc[indicesToKeep, 'principal component 1']
    y = df_components.loc[indicesToKeep, 'principal component 2']
    ax.scatter(x,y,s = 100)
    ax.annotate(target, (x,y))

#for name in targets:  
    
ax.legend(targets)
ax.grid()
# Out:
# ['M. rosenbergii - Espirito Santo-'
#  'P. vannamei - Sergipe - Semi intensivo' 'L. vannamei - Aquafort'
#  'L. vannamei - Northern' 'L. vannamei - Aquacrusta' 'L. vannamei - HM'
#  'L. vannamei - Ilha' 'L. vannamei - Carpixe' 'L. vannamei - Marinus'
#  'L. vannamei - Aquabrasilis' 'L. vannamei - Aquarium - baixa densid.'
#  'L. vannamei - Aquarium - alta densis'
#  'L. vannamei - Aquarium-  bifasico' 'Truta - race-way'
#  'Tilapia - gaiolas - SP -  sem restricao alimentar'
#  'Tilapia - gaiolas - SP - com restricao alimentar'
#  'Tilapia - gaiola - RS' 'Tambatinga - viveiro 2'
#  'Tambatinga - viveiro 23' 'Tambatinga - viveiro 250'
#  'Tambaqui - M amazonicum - policultivo - SP' 'Tilapia - tanque rede - RN'
#  'Lambari - semi intensivo - baixo controle'
#  'Lambari - semi intensivo - médio controle'
#  'Lambari - semi intensivo - alto controle']

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.24602782 0.18855691]
# total variance explained: 0.43458472997066416

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1])}, columns=['cultivo', 'pc1','pc2'])
#df_clustering

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 24           Lambari - semi intensivo - alto controle  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        0
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        0
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 7                               L. vannamei - Carpixe  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 1              P. vannamei - Sergipe - Semi intensivo  ...        1
# 9                          L. vannamei - Aquabrasilis  ...        1
# 13                                   Truta - race-way  ...        1
# 21                         Tilapia - tanque rede - RN  ...        2
# 12                  L. vannamei - Aquarium-  bifasico  ...        2
# 10             L. vannamei - Aquarium - baixa densid.  ...        2
# 11               L. vannamei - Aquarium - alta densis  ...        2
# 5                                    L. vannamei - HM  ...        3
# 4                            L. vannamei - Aquacrusta  ...        3
# 16                              Tilapia - gaiola - RS  ...        3
# 17                             Tambatinga - viveiro 2  ...        3
# 18                            Tambatinga - viveiro 23  ...        3
# 19                           Tambatinga - viveiro 250  ...        3
# 3                              L. vannamei - Northern  ...        3
# 2                              L. vannamei - Aquafort  ...        3
# 22          Lambari - semi intensivo - baixo controle  ...        3
# 0                    M. rosenbergii - Espirito Santo-  ...        3
#
# [25 rows x 4 columns]

# %%
#5 clusters
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50,  marker='x', color="red"); # Show the

# %% [markdown]
# In my view, we have two large clusters and three outliers, as the graph above shows.

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 21                         Tilapia - tanque rede - RN  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        1
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        1
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        1
# 23          Lambari - semi intensivo - médio controle  ...        1
# 24           Lambari - semi intensivo - alto controle  ...        1
# 7                               L. vannamei - Carpixe  ...        1
# 6                                  L. vannamei - Ilha  ...        1
# 8                               L. vannamei - Marinus  ...        1
# 18                            Tambatinga - viveiro 23  ...        2
# 19                           Tambatinga - viveiro 250  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        3
# 13                                   Truta - race-way  ...        3
# 1              P. vannamei - Sergipe - Semi intensivo  ...        3
# 5                                    L. vannamei - HM  ...        4
# 4                            L. vannamei - Aquacrusta  ...        4
# 3                              L. vannamei - Northern  ...        4
# 16                              Tilapia - gaiola - RS  ...        4
# 17                             Tambatinga - viveiro 2  ...        4
# 2                              L. vannamei - Aquafort  ...        4
# 22          Lambari - semi intensivo - baixo controle  ...        4
# 0                    M. rosenbergii - Espirito Santo-  ...        4
#
# [25 rows x 4 columns]

# %%
#6 clusters
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:3])
#print(model.cluster_centers_)

#Plot clusters
plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, marker='x', color="red"); # Show the 

#7 clusters

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 5                                    L. vannamei - HM  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 21                         Tilapia - tanque rede - RN  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 8                               L. vannamei - Marinus  ...        3
# 7                               L. vannamei - Carpixe  ...        3
# 18                            Tambatinga - viveiro 23  ...        3
# 19                           Tambatinga - viveiro 250  ...        3
# 4                            L. vannamei - Aquacrusta  ...        3
# 13                                   Truta - race-way  ...        4
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        4
# 23          Lambari - semi intensivo - médio controle  ...        5
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        5
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        5
# 6                                  L. vannamei - Ilha  ...        5
# 24           Lambari - semi intensivo - alto controle  ...        5
#
# [25 rows x 4 columns]

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 5                                    L. vannamei - HM  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 21                         Tilapia - tanque rede - RN  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 8                               L. vannamei - Marinus  ...        3
# 7                               L. vannamei - Carpixe  ...        3
# 18                            Tambatinga - viveiro 23  ...        3
# 19                           Tambatinga - viveiro 250  ...        3
# 4                            L. vannamei - Aquacrusta  ...        3
# 13                                   Truta - race-way  ...        4
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        4
# 23          Lambari - semi intensivo - médio controle  ...        5
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        5
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        5
# 6                                  L. vannamei - Ilha  ...        5
# 24           Lambari - semi intensivo - alto controle  ...        5
#
# [25 rows x 4 columns]

# %% [markdown]
# Now we analyze 3 Principal Components

# %%
#Normalize the data to have MEAN==0
from sklearn.preprocessing import StandardScaler

x = df_cultivo.iloc[:,1:].values
x = StandardScaler().fit_transform(x) # normalizing the features
#print(x)

# %%
#Run PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=3)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
finalDf = pd.concat([principalDf, df_cultivo[['cultivo']]], axis = 1)

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]), 'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])}, columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#Visualize results of PCA in Three Dimensions
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    
ax.legend(targets)
ax.grid()

# %%
variance_list =pca.explained_variance_ratio_
print("variance explained by each component:", variance_list)
print("total variance explained:", sum(variance_list))
# Out:
# variance explained by each component: [0.24602782 0.18855691 0.14401527]
# total variance explained: 0.5785999972701577

# %% [markdown]
# Now we search for clusters for 3 principal components

# %%
#4 clusters 
from sklearn.cluster import KMeans
model = KMeans(4)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
   
ax.legend(targets)
ax.grid()

# %%
#principal components for each indicador
#print(principalComponents)
#print(targets)
df_clustering = pd.DataFrame({'cultivo': targets,  'pc1':list(principalComponents[:,0]),
                              'pc2': list(principalComponents[:,1]),'pc3': list(principalComponents[:,2])},
                              columns=['cultivo', 'pc1','pc2','pc3'])
#df_clustering

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 18                            Tambatinga - viveiro 23  ...        0
# 16                              Tilapia - gaiola - RS  ...        0
# 2                              L. vannamei - Aquafort  ...        0
# 3                              L. vannamei - Northern  ...        0
# 4                            L. vannamei - Aquacrusta  ...        0
# 5                                    L. vannamei - HM  ...        0
# 6                                  L. vannamei - Ilha  ...        0
# 19                           Tambatinga - viveiro 250  ...        0
# 8                               L. vannamei - Marinus  ...        0
# 17                             Tambatinga - viveiro 2  ...        0
# 13                                   Truta - race-way  ...        1
# 21                         Tilapia - tanque rede - RN  ...        1
# 12                  L. vannamei - Aquarium-  bifasico  ...        1
# 10             L. vannamei - Aquarium - baixa densid.  ...        1
# 11               L. vannamei - Aquarium - alta densis  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        3
# 22          Lambari - semi intensivo - baixo controle  ...        3
# 0                    M. rosenbergii - Espirito Santo-  ...        3
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        3
# 23          Lambari - semi intensivo - médio controle  ...        3
# 7                               L. vannamei - Carpixe  ...        3
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        3
# 24           Lambari - semi intensivo - alto controle  ...        3
#
# [25 rows x 5 columns]

# %% [markdown]
# Comparing k-means of PC12 with PC123, we see that the cluster membership changes completely.

# %%
#5 clusters 
from sklearn.cluster import KMeans
model = KMeans(5)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)
    #ax.annotate(target, (x,y))

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 

#for name in targets:  
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 0                    M. rosenbergii - Espirito Santo-  ...        0
# 22          Lambari - semi intensivo - baixo controle  ...        0
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        0
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        0
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        0
# 23          Lambari - semi intensivo - médio controle  ...        0
# 7                               L. vannamei - Carpixe  ...        0
# 24           Lambari - semi intensivo - alto controle  ...        0
# 9                          L. vannamei - Aquabrasilis  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        1
# 8                               L. vannamei - Marinus  ...        2
# 2                              L. vannamei - Aquafort  ...        2
# 19                           Tambatinga - viveiro 250  ...        2
# 18                            Tambatinga - viveiro 23  ...        2
# 17                             Tambatinga - viveiro 2  ...        2
# 6                                  L. vannamei - Ilha  ...        2
# 16                              Tilapia - gaiola - RS  ...        2
# 4                            L. vannamei - Aquacrusta  ...        2
# 5                                    L. vannamei - HM  ...        2
# 3                              L. vannamei - Northern  ...        2
# 11               L. vannamei - Aquarium - alta densis  ...        3
# 21                         Tilapia - tanque rede - RN  ...        3
# 10             L. vannamei - Aquarium - baixa densid.  ...        3
# 12                  L. vannamei - Aquarium-  bifasico  ...        3
# 13                                   Truta - race-way  ...        4
#
# [25 rows x 5 columns]

# %%
#6 clusters 
from sklearn.cluster import KMeans
model = KMeans(6)
model.fit(df_clustering.iloc[:,1:4])
#print(model.cluster_centers_)

#Plot clusters
#plt.scatter(df_clustering.iloc[:,1],df_clustering.iloc[:,2], c=model.labels_.astype(float));
#plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=50, color="red"); # Show the 

fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3-components PCA', fontsize = 20)
targets = df_cultivo['cultivo'].to_numpy()

for target in targets:
    indicesToKeep = finalDf['cultivo'] == target
    x = finalDf.loc[indicesToKeep, 'principal component 1']
    y = finalDf.loc[indicesToKeep, 'principal component 2']
    z = finalDf.loc[indicesToKeep, 'principal component 3']
    ax.scatter(x,y,z,s = 100)

ax.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1],model.cluster_centers_[:,2], s=150, marker='x', color="black"); # Show the 
    
ax.legend(targets)
ax.grid()

# %%
#To which cluster each point belongs?
df1= df_clustering.assign(cluster=pd.Series(model.labels_).values)
df1.sort_values(by='cluster')
# Out:
#                                               cultivo  ...  cluster
# 12                  L. vannamei - Aquarium-  bifasico  ...        0
# 21                         Tilapia - tanque rede - RN  ...        0
# 10             L. vannamei - Aquarium - baixa densid.  ...        0
# 11               L. vannamei - Aquarium - alta densis  ...        0
# 2                              L. vannamei - Aquafort  ...        1
# 3                              L. vannamei - Northern  ...        1
# 4                            L. vannamei - Aquacrusta  ...        1
# 5                                    L. vannamei - HM  ...        1
# 19                           Tambatinga - viveiro 250  ...        1
# 18                            Tambatinga - viveiro 23  ...        1
# 17                             Tambatinga - viveiro 2  ...        1
# 16                              Tilapia - gaiola - RS  ...        1
# 1              P. vannamei - Sergipe - Semi intensivo  ...        2
# 9                          L. vannamei - Aquabrasilis  ...        2
# 20         Tambaqui - M amazonicum - policultivo - SP  ...        3
# 24           Lambari - semi intensivo - alto controle  ...        3
# 14  Tilapia - gaiolas - SP -  sem restricao alimentar  ...        3
# 23          Lambari - semi intensivo - médio controle  ...        3
# 8                               L. vannamei - Marinus  ...        3
# 7                               L. vannamei - Carpixe  ...        3
# 6                                  L. vannamei - Ilha  ...        3
# 15   Tilapia - gaiolas - SP - com restricao alimentar  ...        3
# 22          Lambari - semi intensivo - baixo controle  ...        4
# 0                    M. rosenbergii - Espirito Santo-  ...        4
# 13                                   Truta - race-way  ...        5
#
# [25 rows x 5 columns]
